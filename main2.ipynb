# %%
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import yfinance as yf
yf.pdr_override()

# %%
dataset = pd.read_csv('db/acoes1.csv')

dataset
# Out:
#            Date    VALE3.SA   RECV3.SA   KEPL3.SA  CURY3.SA   VULC3.SA  \
# 0    2021-05-05  110.709999  15.610000   8.475000      9.85   7.810000
# 1    2021-05-06  115.050003  16.000000   8.896666      9.92   8.020000
# 2    2021-05-07  115.449997  16.600000   8.858333     10.09   8.380000
# 3    2021-05-10  114.690002  15.880000   8.895000     10.25   8.170000
# 4    2021-05-11  118.720001  16.150000   8.913333     10.20   8.370000
# ..          ...         ...        ...        ...       ...        ...
# 612  2023-10-16   67.300003  22.190001  10.760000     15.10  18.860001
# 613  2023-10-17   67.849998  21.660000  10.600000     14.65  18.590000
# 614  2023-10-18   65.360001  21.790001  10.440000     14.29  18.540001
# 615  2023-10-19   64.419998  21.799999  10.420000     14.47  18.580000
# 616  2023-10-20   62.410000  21.650000  10.350000     14.20  18.370001
#
#       LEVE3.SA   GGBR4.SA   LREN3.SA   ALSO3.SA  ...   CLSC4.SA   CMIG4.SA  \
# ...

# %%
((dataset['VALE3.SA'][len(dataset) - 1] - dataset['VALE3.SA'][0]) / dataset['VALE3.SA'][0]) * 100
# Out:
# -43.627494929529576

# %%
df = pd.DataFrame()
valor_tot= 0
for acao in dataset.columns[1:]:
     valor =int(((dataset[acao][len(dataset) - 1] - dataset[acao][0]) / dataset[acao][0]) * 100)
     print(f'empresa {acao} e o valor é {round(valor,2)}')
     d = valor
     valor_tot = valor_tot + d
     
print(valor_tot)
# Out:
# empresa VALE3.SA e o valor é -43
# empresa RECV3.SA e o valor é 38
# empresa KEPL3.SA e o valor é 22
# empresa CURY3.SA e o valor é 44
# empresa VULC3.SA e o valor é 135
# empresa LEVE3.SA e o valor é 54
# empresa GGBR4.SA e o valor é -34
# empresa LREN3.SA e o valor é -67
# empresa ALSO3.SA e o valor é -19
# empresa DIRR3.SA e o valor é 30
# empresa MILS3.SA e o valor é 25
# empresa RANI3.SA e o valor é 46
# empresa CAMB3.SA e o valor é 60
# empresa CSUD3.SA e o valor é -42
# empresa CLSC4.SA e o valor é -6
# empresa CMIG4.SA e o valor é 26
# empresa ITSA4.SA e o valor é -1
# empresa BBAS3.SA e o valor é 69
# empresa TASA4.SA e o valor é -39
# empresa SLCE3.SA e o valor é -17
# empresa B3SA3.SA e o valor é -35
# empresa PETR4.SA e o valor é 58
# empresa SUZB3.SA e o valor é -19
# empresa KLBN4.SA e o valor é -17
# 268
